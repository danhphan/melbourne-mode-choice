# %%
import pandas as pd
import config

# %%
pd.set_option('display.max_rows',100)

# %% [markdown]
# ### Load and process trips data

# %%
trips = pd.read_csv(config.TRIPS_1216_RAW, low_memory=False)
trips.shape
# Out:
# (128684, 90)

# %%
trips.head(5).T
# Out:
#                                          0                       1  \
# TRIPID                   Y12H0000101P01T01       Y12H0000101P01T02
# PERSID                      Y12H0000101P01          Y12H0000101P01
# HHID                           Y12H0000101             Y12H0000101
# TRIPNO                                   1                       2
# TRAVDOW                             Monday                  Monday
# STOPS                                    1                       1
# STARTHOUR                                8                      17
# STARTIME                               525                    1050
# ARRHOUR                                  9                      17
# ARRTIME                                545                    1075
# ORIGSTOP                 Y12H0000101P01S01       Y12H0000101P01S02
# DESTSTOP                 Y12H0000101P01S01       Y12H0000101P01S02
# ORIGSA1                        20904122028             20904121869
# ORIGSA3                Whittlesea - Wallan     Whittlesea - Wallan
# ORIGLGA                     Whittlesea (C)          Whittlesea (C)
# ORIGPLACE1                   Accommodation               Workplace
# ORIGPLACE2                     Survey Home            My Workplace
# ORIGPURP1                    At or Go Home            Work Related
# ORIGPURP2                    At or Go Home           Own Workplace
# DESTPLACE1                       Workplace           Accommodation
# DESTPLACE2                    My Workplace             Survey Home
# DESTPURP1                     Work Related           At or Go Home
# DESTPURP2                    Own Workplace           At or Go Home
# DESTSA1                        20904121869             20904122028
# DESTSA3                Whittlesea - Wallan     Whittlesea - Wallan
# DESTLGA                     Whittlesea (C)          Whittlesea (C)
# CUMDIST                               7.45                    7.45
# DEPHOUR                                 17                     NaN
# DEPTIME                               1050                     NaN
# MODESTOPID               Y12H0000101P01S01       Y12H0000101P01S02
# LINKMODE                    Vehicle Driver          Vehicle Driver
# TRIPTIME                                20                      25
# TRAVTIME                                20                      25
# WAITIME                                  0                       0
# DURATION                               505                     NaN
# Mode1                       Vehicle Driver          Vehicle Driver
# Mode2                                  NaN                     NaN
# Mode3                                  NaN                     NaN
# Mode4                                  NaN                     NaN
# Mode5                                  NaN                     NaN
# Mode6                                  NaN                     NaN
# Mode7                                  NaN                     NaN
# Mode8                                  NaN                     NaN
# Mode9                                  NaN                     NaN
# Time1                                   20                      25
# Time2                                  NaN                     NaN
# Time3                                  NaN                     NaN
# Time4                                  NaN                     NaN
# Time5                                  NaN                     NaN
# Time6                                  NaN                     NaN
# Time7                                  NaN                     NaN
# Time8                                  NaN                     NaN
# Time9                                  NaN                     NaN
# Dist1                                 7.45                    7.45
# Dist2                                  NaN                     NaN
# Dist3                                  NaN                     NaN
# Dist4                                  NaN                     NaN
# Dist5                                  NaN                     NaN
# Dist6                                  NaN                     NaN
# Dist7                                  NaN                     NaN
# Dist8                                  NaN                     NaN
# Dist9                                  NaN                     NaN
# TRIPPURP                      Work Related            Work Related
# Mode_Group                  Vehicle Driver          Vehicle Driver
# DIST_GRP                           7 - 7.9                 7 - 7.9
# Time_Grp                           20 - 24                 25 - 29
# STUDYING                          No Study                No Study
# HomeSA1                        20904122028             20904122028
# HomeSA2                  Mill Park - North       Mill Park - North
# HomeSA3                Whittlesea - Wallan     Whittlesea - Wallan
# HomeSA4             Melbourne - North East  Melbourne - North East
# HOMELGA                     Whittlesea (C)          Whittlesea (C)
# HomeRegion_ASGS            Melbourne GCCSA         Melbourne GCCSA
# HomeSubRegion_ASGS            MELB - Outer            MELB - Outer
# CW_ADTRIPWGT_SA3                     94.73                   94.73
# CW_WDTRIPWGT_SA3                    137.04                  137.04
# CW_WETRIPWGT_SA3
# RP_ADTRIPWGT_SA3                    169.12                  169.12
# RP_WDTRIPWGT_SA3                     260.4                   260.4
# RP_WETRIPWGT_SA3
# ReportingPeriod                    2012-14                 2012-14
# HomeSubRegion_ASGC             MSD - Outer             MSD - Outer
# HomeRegion_ASGC                 MSD_31LGAs              MSD_31LGAs
# TRAVELPERIOD          AM Peak (7am to 9am)    PM Peak (3pm to 6pm)
# RP_ADTRIPWGT_LGA                    161.55                  161.55
# RP_WDTRIPWGT_LGA                    235.86                  235.86
# RP_WETRIPWGT_LGA
# CW_ADTRIPWGT_LGA                      91.9                    91.9
# CW_WDTRIPWGT_LGA                    162.34                  162.34
# CW_WETRIPWGT_LGA
#
#                                                  2  \
# TRIPID                           Y12H0000101P02T01
# PERSID                              Y12H0000101P02
# HHID                                   Y12H0000101
# TRIPNO                                           1
# TRAVDOW                                     Monday
# STOPS                                            1
# STARTHOUR                                        8
# STARTIME                                       500
# ARRHOUR                                          8
# ARRTIME                                        520
# ORIGSTOP                         Y12H0000101P02S01
# DESTSTOP                         Y12H0000101P02S01
# ORIGSA1                                20904122028
# ORIGSA3                        Whittlesea - Wallan
# ORIGLGA                             Whittlesea (C)
# ORIGPLACE1                           Accommodation
# ORIGPLACE2                             Survey Home
# ORIGPURP1                            At or Go Home
# ORIGPURP2                            At or Go Home
# DESTPLACE1                      Place of Education
# DESTPLACE2                          Primary School
# DESTPURP1              Pick-up or Drop-off Someone
# DESTPURP2           Someone picked-up or delivered
# DESTSA1                                20904122031
# DESTSA3                        Whittlesea - Wallan
# DESTLGA                             Whittlesea (C)
# CUMDIST                                       3.92
# DEPHOUR                                          9
# DEPTIME                                        540
# MODESTOPID                       Y12H0000101P02S01
# LINKMODE                            Vehicle Driver
# TRIPTIME                                        20
# TRAVTIME                                        20
# WAITIME                                          0
# DURATION                                        20
# Mode1                               Vehicle Driver
# Mode2                                          NaN
# Mode3                                          NaN
# Mode4                                          NaN
# Mode5                                          NaN
# Mode6                                          NaN
# Mode7                                          NaN
# Mode8                                          NaN
# Mode9                                          NaN
# Time1                                           20
# Time2                                          NaN
# Time3                                          NaN
# Time4                                          NaN
# Time5                                          NaN
# Time6                                          NaN
# Time7                                          NaN
# Time8                                          NaN
# Time9                                          NaN
# Dist1                                         3.92
# Dist2                                          NaN
# Dist3                                          NaN
# Dist4                                          NaN
# Dist5                                          NaN
# Dist6                                          NaN
# Dist7                                          NaN
# Dist8                                          NaN
# Dist9                                          NaN
# TRIPPURP               Pick-up or Drop-off Someone
# Mode_Group                          Vehicle Driver
# DIST_GRP                                   3 - 3.9
# Time_Grp                                   20 - 24
# STUDYING                                  No Study
# HomeSA1                                20904122028
# HomeSA2                          Mill Park - North
# HomeSA3                        Whittlesea - Wallan
# HomeSA4                     Melbourne - North East
# HOMELGA                             Whittlesea (C)
# HomeRegion_ASGS                    Melbourne GCCSA
# HomeSubRegion_ASGS                    MELB - Outer
# CW_ADTRIPWGT_SA3                              90.7
# CW_WDTRIPWGT_SA3                            128.57
# CW_WETRIPWGT_SA3
# RP_ADTRIPWGT_SA3                            170.04
# RP_WDTRIPWGT_SA3                            258.35
# RP_WETRIPWGT_SA3
# ReportingPeriod                            2012-14
# HomeSubRegion_ASGC                     MSD - Outer
# HomeRegion_ASGC                         MSD_31LGAs
# TRAVELPERIOD                  AM Peak (7am to 9am)
# RP_ADTRIPWGT_LGA                            162.11
# RP_WDTRIPWGT_LGA                            234.25
# RP_WETRIPWGT_LGA
# CW_ADTRIPWGT_LGA                             87.78
# CW_WDTRIPWGT_LGA                            151.88
# CW_WETRIPWGT_LGA
#
#                                                  3                       4
# TRIPID                           Y12H0000101P02T02       Y12H0000101P02T03
# PERSID                              Y12H0000101P02          Y12H0000101P02
# HHID                                   Y12H0000101             Y12H0000101
# TRIPNO                                           2                       3
# TRAVDOW                                     Monday                  Monday
# STOPS                                            1                       1
# STARTHOUR                                        9                      10
# STARTIME                                       540                     600
# ARRHOUR                                          9                      10
# ARRTIME                                        550                     610
# ORIGSTOP                         Y12H0000101P02S02       Y12H0000101P02S03
# DESTSTOP                         Y12H0000101P02S02       Y12H0000101P02S03
# ORIGSA1                                20904122031             20904122002
# ORIGSA3                        Whittlesea - Wallan     Whittlesea - Wallan
# ORIGLGA                             Whittlesea (C)          Whittlesea (C)
# ORIGPLACE1                      Place of Education                   Shops
# ORIGPLACE2                          Primary School         Shopping Centre
# ORIGPURP1              Pick-up or Drop-off Someone           Buy Something
# ORIGPURP2           Someone picked-up or delivered        Bought something
# DESTPLACE1                                   Shops           Accommodation
# DESTPLACE2                         Shopping Centre             Survey Home
# DESTPURP1                            Buy Something           At or Go Home
# DESTPURP2                         Bought something           At or Go Home
# DESTSA1                                20904122002             20904122028
# DESTSA3                        Whittlesea - Wallan     Whittlesea - Wallan
# DESTLGA                             Whittlesea (C)          Whittlesea (C)
# CUMDIST                                        2.5                    2.55
# DEPHOUR                                         10                      14
# DEPTIME                                        600                     890
# MODESTOPID                       Y12H0000101P02S02       Y12H0000101P02S03
# LINKMODE                            Vehicle Driver          Vehicle Driver
# TRIPTIME                                        10                      10
# TRAVTIME                                        10                      10
# WAITIME                                          0                       0
# DURATION                                        50                     280
# Mode1                               Vehicle Driver          Vehicle Driver
# Mode2                                          NaN                     NaN
# Mode3                                          NaN                     NaN
# Mode4                                          NaN                     NaN
# Mode5                                          NaN                     NaN
# Mode6                                          NaN                     NaN
# Mode7                                          NaN                     NaN
# Mode8                                          NaN                     NaN
# Mode9                                          NaN                     NaN
# Time1                                           10                      10
# Time2                                          NaN                     NaN
# Time3                                          NaN                     NaN
# Time4                                          NaN                     NaN
# Time5                                          NaN                     NaN
# Time6                                          NaN                     NaN
# Time7                                          NaN                     NaN
# Time8                                          NaN                     NaN
# Time9                                          NaN                     NaN
# Dist1                                          2.5                    2.55
# Dist2                                          NaN                     NaN
# Dist3                                          NaN                     NaN
# Dist4                                          NaN                     NaN
# Dist5                                          NaN                     NaN
# Dist6                                          NaN                     NaN
# Dist7                                          NaN                     NaN
# Dist8                                          NaN                     NaN
# Dist9                                          NaN                     NaN
# TRIPPURP                             Buy Something           Buy Something
# Mode_Group                          Vehicle Driver          Vehicle Driver
# DIST_GRP                                   2 - 2.9                 2 - 2.9
# Time_Grp                                    Oct-14                  Oct-14
# STUDYING                                  No Study                No Study
# HomeSA1                                20904122028             20904122028
# HomeSA2                          Mill Park - North       Mill Park - North
# HomeSA3                        Whittlesea - Wallan     Whittlesea - Wallan
# HomeSA4                     Melbourne - North East  Melbourne - North East
# HOMELGA                             Whittlesea (C)          Whittlesea (C)
# HomeRegion_ASGS                    Melbourne GCCSA         Melbourne GCCSA
# HomeSubRegion_ASGS                    MELB - Outer            MELB - Outer
# CW_ADTRIPWGT_SA3                              90.7                    90.7
# CW_WDTRIPWGT_SA3                            128.57                  128.57
# CW_WETRIPWGT_SA3
# RP_ADTRIPWGT_SA3                            170.04                  170.04
# RP_WDTRIPWGT_SA3                            258.35                  258.35
# RP_WETRIPWGT_SA3
# ReportingPeriod                            2012-14                 2012-14
# HomeSubRegion_ASGC                     MSD - Outer             MSD - Outer
# HomeRegion_ASGC                         MSD_31LGAs              MSD_31LGAs
# TRAVELPERIOD                              Off Peak                Off Peak
# RP_ADTRIPWGT_LGA                            162.11                  162.11
# RP_WDTRIPWGT_LGA                            234.25                  234.25
# RP_WETRIPWGT_LGA
# CW_ADTRIPWGT_LGA                             87.78                   87.78
# CW_WDTRIPWGT_LGA                            151.88                  151.88
# CW_WETRIPWGT_LGA

# %%
trips.Mode1.value_counts()
# Out:
# Vehicle Driver       66976
# Vehicle Passenger    30640
# Walking              27545
# Bicycle               2150
# Taxi                   376
# Other                  366
# Motorcycle             292
# School Bus             219
# Train                   79
# Public Bus              28
# Tram                    13
# Name: Mode1, dtype: int64

# %%
trips.LINKMODE.value_counts()
# Out:
# Vehicle Driver       66751
# Vehicle Passenger    30301
# Walking              20277
# Train                 5065
# Bicycle               2080
# Tram                  1375
# Public Bus            1238
# School Bus             592
# Taxi                   378
# Other                  335
# Motorcycle             292
# Name: LINKMODE, dtype: int64

# %%
trips.columns
# Out:
# Index(['TRIPID', 'PERSID', 'HHID', 'TRIPNO', 'TRAVDOW', 'STOPS', 'STARTHOUR',
#        'STARTIME', 'ARRHOUR', 'ARRTIME', 'ORIGSTOP', 'DESTSTOP', 'ORIGSA1',
#        'ORIGSA3', 'ORIGLGA', 'ORIGPLACE1', 'ORIGPLACE2', 'ORIGPURP1',
#        'ORIGPURP2', 'DESTPLACE1', 'DESTPLACE2', 'DESTPURP1', 'DESTPURP2',
#        'DESTSA1', 'DESTSA3', 'DESTLGA', 'CUMDIST', 'DEPHOUR', 'DEPTIME',
#        'MODESTOPID', 'LINKMODE', 'TRIPTIME', 'TRAVTIME', 'WAITIME', 'DURATION',
#        'Mode1', 'Mode2', 'Mode3', 'Mode4', 'Mode5', 'Mode6', 'Mode7', 'Mode8',
#        'Mode9', 'Time1', 'Time2', 'Time3', 'Time4', 'Time5', 'Time6', 'Time7',
#        'Time8', 'Time9', 'Dist1', 'Dist2', 'Dist3', 'Dist4', 'Dist5', 'Dist6',
#        'Dist7', 'Dist8', 'Dist9', 'TRIPPURP', 'Mode_Group', 'DIST_GRP',
#        'Time_Grp', 'STUDYING', 'HomeSA1', 'HomeSA2', 'HomeSA3', 'HomeSA4',
#        'HOMELGA', 'HomeRegion_ASGS', 'HomeSubRegion_ASGS', 'CW_ADTRIPWGT_SA3',
#        'CW_WDTRIPWGT_SA3', 'CW_WETRIPWGT_SA3', 'RP_ADTRIPWGT_SA3',
#        'RP_WDTRIPWGT_SA3', 'RP_WETRIPWGT_SA3', 'ReportingPeriod',
#        'HomeSubRegion_ASGC', 'HomeRegion_ASGC', 'TRAVELPERIOD',
#        'RP_ADTRIPWGT_LGA', 'RP_WDTRIPWGT_LGA', 'RP_WETRIPWGT_LGA',
#        'CW_ADTRIPWGT_LGA', 'CW_WDTRIPWGT_LGA', 'CW_WETRIPWGT_LGA'],
#       dtype='object')

# %% [markdown]
# ### Select related columns

# %%
columns = ['TRIPID', 'PERSID', 'HHID', 'TRIPNO', 'TRAVDOW', 'LINKMODE', 'TRIPPURP','DESTPURP1',
           'STARTIME', 'ARRTIME', 'TRIPTIME', 'TRAVTIME', 'WAITIME', 
           'ORIGSA1', 'DESTSA1', 'CUMDIST', 'HomeSA1',]

# %%
trips = trips[columns]

# %%
trips.LINKMODE.value_counts()
# Out:
# Vehicle Driver       66751
# Vehicle Passenger    30301
# Walking              20277
# Train                 5065
# Bicycle               2080
# Tram                  1375
# Public Bus            1238
# School Bus             592
# Taxi                   378
# Other                  335
# Motorcycle             292
# Name: LINKMODE, dtype: int64

# %% [markdown]
# ### Process main travel mode from LinkMode

# %%
trips.LINKMODE.value_counts()
# Out:
# Vehicle Driver       66751
# Vehicle Passenger    30301
# Walking              20277
# Train                 5065
# Bicycle               2080
# Tram                  1375
# Public Bus            1238
# School Bus             592
# Taxi                   378
# Other                  335
# Motorcycle             292
# Name: LINKMODE, dtype: int64

# %%
# Map to 4 main travel modes: Walk, Car, Train, CycleTRIPPURP
mode_mapping = {'Walking':'Walk', 'Vehicle Driver': 'Car', 'Vehicle Passenger': 'Car', 'Taxi': 'Car',
                'Bicycle':'Cycle', 'Train':'Train', 'Tram':'Train', 'Public Bus': 'Car',}

trips['Mode'] = trips.LINKMODE.map(mode_mapping)

# %%
trips['Mode'].value_counts()
# Out:
# Car      98668
# Walk     20277
# Train     6440
# Cycle     2080
# Name: Mode, dtype: int64

# %% [markdown]
# ### Process trip purpose

# %%
trips.DESTPURP1.value_counts()
# Out:
# At or Go Home                   50451
# Work Related                    16476
# Buy Something                   13870
# Social                          13031
# Pick-up or Drop-off Someone      9331
# Personal Business                7163
# Recreational                     6773
# Education                        4962
# Accompany Someone                4173
# Pick-up or Deliver Something     1841
# Other Purpose                     486
# Change Mode                       125
# Not Stated                          2
# Name: DESTPURP1, dtype: int64

# %%
trips.TRIPPURP.value_counts()
# Out:
# Work Related                         26746
# Buy Something                        23220
# Social                               21006
# Pick-up or Drop-off Someone          14558
# Recreational                         11828
# Personal Business                    11461
# Education                             8774
# Accompany Someone                     6873
# Pick-up or Deliver Something          2784
# Other Purpose                          752
# Unknown purpose (at start of day)      446
# Change Mode                            170
# At or Go Home                           64
# Not Stated                               2
# Name: TRIPPURP, dtype: int64

# %%
# Map trip purpose
mapping = {"Work Related":"Work", "Buy Something":"Shopping", "Social":"Social", "Pick-up or Drop-off Someone":"Pick-up_Drop-off",
           "Recreational":"Recreational","Personal Business":"Personal Business","Education":"Education","Accompany Someone":"Pick-up_Drop-off",
           "Pick-up or Deliver Something":"Pick-up_Drop-off", "Other Purpose":"Other", "Unknown purpose (at start of day)":"Other",
           "Change Mode":"Other", "At or Go Home":"Other", "Not Stated":"Other"}
trips.TRIPPURP = trips.TRIPPURP.map(mapping)

# %%
trips.TRIPPURP.value_counts()
# Out:
# Work                 26746
# Pick-up_Drop-off     24215
# Shopping             23220
# Social               21006
# Recreational         11828
# Personal Business    11461
# Education             8774
# Other                 1434
# Name: TRIPPURP, dtype: int64

# %% [markdown]
# ### Select people with at least one trip with active mode (Walking, Bicycle)

# %%
# How many people have at leat one active mode trip
trips[trips.LINKMODE.isin(['Walking','Bicycle'])].PERSID.nunique()
# Out:
# 9679

# %%
active_persons = trips[trips.LINKMODE.isin(['Walking','Bicycle'])].PERSID.unique()
type(active_persons), len(active_persons)
# Out:
# (numpy.ndarray, 9679)

# %%
# Get trips of these active persons
trips_ap = trips[trips.PERSID.isin(active_persons)]
trips_ap.shape
# Out:
# (44592, 18)

# %%
trips_ap.isna().sum()
# Out:
# TRIPID         0
# PERSID         0
# HHID           0
# TRIPNO         0
# TRAVDOW        0
# LINKMODE       0
# TRIPPURP       0
# DESTPURP1      0
# STARTIME       0
# ARRTIME        0
# TRIPTIME       0
# TRAVTIME       0
# WAITIME        0
# ORIGSA1        0
# DESTSA1        0
# CUMDIST        0
# HomeSA1        0
# Mode         241
# dtype: int64

# %%
trips_ap = trips_ap.dropna()

# %%
trips_ap.shape
# Out:
# (44351, 18)

# %% [markdown]
# ### Save to csv file for further analysis

# %%
trips_ap['Mode'].value_counts()
# Out:
# Walk     20277
# Car      19823
# Train     2171
# Cycle     2080
# Name: Mode, dtype: int64

# %%
trips_ap.to_csv(config.TRIPS_1216_PRC, index=False)

# %%
trips_ap.columns
# Out:
# Index(['TRIPID', 'PERSID', 'HHID', 'TRIPNO', 'TRAVDOW', 'LINKMODE', 'TRIPPURP',
#        'DESTPURP1', 'STARTIME', 'ARRTIME', 'TRIPTIME', 'TRAVTIME', 'WAITIME',
#        'ORIGSA1', 'DESTSA1', 'CUMDIST', 'HomeSA1', 'Mode'],
#       dtype='object')

# %%
trips_ap.head()
# Out:
#                TRIPID          PERSID         HHID  TRIPNO TRAVDOW  \
# 40  Y12H0000107P01T01  Y12H0000107P01  Y12H0000107       1  Sunday
# 41  Y12H0000107P01T02  Y12H0000107P01  Y12H0000107       2  Sunday
# 42  Y12H0000107P01T03  Y12H0000107P01  Y12H0000107       3  Sunday
# 43  Y12H0000107P01T04  Y12H0000107P01  Y12H0000107       4  Sunday
# 44  Y12H0000107P02T01  Y12H0000107P02  Y12H0000107       1  Sunday
#
#              LINKMODE      TRIPPURP      DESTPURP1  STARTIME  ARRTIME  \
# 40     Vehicle Driver        Social         Social       630      650
# 41     Vehicle Driver        Social  At or Go Home       750      760
# 42            Walking  Recreational   Recreational       810      840
# 43            Walking  Recreational  At or Go Home       855      885
# 44  Vehicle Passenger        Social         Social       630      650
#
#     TRIPTIME  TRAVTIME  WAITIME      ORIGSA1      DESTSA1  CUMDIST  \
# 40        20        20        0  20904122028  20904122002     2.60
# 41        10        10        0  20904122002  20904122028     2.60
# 42        30        30        0  20904122028  20904122031     3.23
# 43        30        30        0  20904122031  20904122028     3.23
# 44        20        20        0  20904122028  20904122002     2.60
#
#         HomeSA1  Mode
# 40  20904122028   Car
# 41  20904122028   Car
# 42  20904122028  Walk
# 43  20904122028  Walk
# 44  20904122028   Car
